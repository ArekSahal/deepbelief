# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
path = "/content/drive/MyDrive/bm/"
sys.path.append(path)

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from dbimage_torch import DBImage
plt.rcParams['image.cmap'] = 'Greys_r'

print("Loading MNIST dataset")
with open(path+'data/train_data.npy', 'rb') as f:
    train_X = torch.from_numpy(np.load(f))
with open(path+'data/train_labels.npy', 'rb') as f:
    train_labels = torch.from_numpy(np.load(f))
with open(path+'data/test_data.npy', 'rb') as f:
    test_X = torch.from_numpy(np.load(f))
with open(path+'data/test_labels.npy', 'rb') as f:
    test_labels = torch.from_numpy(np.load(f))


print("Done loading MNIST")
n_train = 60000
n_test = 10000

test_X = test_X[:n_test,:,:].float()
train_X = train_X[:n_train,:,:].float()
test_labels = test_labels[:n_test].float()
train_labels = train_labels[:n_train].float()

cdns = [1,1,1]

model = DBImage(28,28,10,[500,500,2000],
                batch_size=100,
                learning_rate=0.01,
                momentum=0.5,
                late_momentum=0.9,
                weight_decay=2*10**(-4),
                tune_momentum=0.1,
                tune_rate=0.001, 
                tune_decay=0.0007, 
                cdns=cdns,
                sparsity_target=0.05,
                sparsity_penalty=0.00001)

model.set_images(train_X, train_labels,split=0.9)

#model.load_weights(path+"models/db_")


model.train(50,save=True, filename=path + "models/db_", full_loss=True)
model.validate(test_X,test_labels,filename=path+"figures/DBN/", full=True)
#model.tune(20,save=True,filename=path+"models/db_")
#model.validate(test_X,test_labels,full=False,filename=path+"figures/DBN/")
# Out:
# Using CPU
# Loading MNIST dataset
# Done loading MNIST
# 784 500
# 500 500
# 510 2000
# HBox(children=(FloatProgress(value=0.0, description='Greedy layer-by-layer training', max=3.0, style=ProgressS…
# HBox(children=(FloatProgress(value=0.0, description='Training Layer', max=50.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Mini-batch', max=540.0, style=ProgressStyle(description_w…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d668c4faa7c0> in <module>()
#      45
#      46
# ---> 47 model.train(50,save=True, filename=path + "models/db_", full_loss=True)
#      48 model.validate(test_X,test_labels,filename=path+"figures/DBN/", full=True)
#      49 #model.tune(20,save=True,filename=path+"models/db_")
#
# /content/drive/MyDrive/bm/dbimage_torch.py in train(self, epochs, save, filename, test, full_loss)
#      26
#      27     def train(self,epochs,save=True, filename="models/db",test=False, full_loss=False):
# ---> 28         self.model.train(epochs,save, filename=filename,test=test,full_loss=full_loss)
#      29
#      30     def validate(self, test_data, test_labels, full=True, filename="figures/DBN/", no_print=False):
#
# /content/drive/MyDrive/bm/dbnet_torch.py in train(self, epochs, save, filename, test, full_loss)
#     101                 #print("Training layer: ", m)
#     102                 self.stack[m].set_training_data(data, val_data)
# --> 103                 self.stack[m].train(epochs,save=save, filename=filename + str(m),test=test,full_loss=full_loss)
#     104                 if save:
#     105                     self.stack[m].save_weights(filename=filename + str(m))
#
# /content/drive/MyDrive/bm/bm_torch.py in train(self, epochs, save, filename, full_loss, test)
#     216
#     217             # --------- TENSORBOARD ------------
# --> 218             self.writer.add_histogram("Weights", torch.abs(self.w.flatten()), global_step=ep)
#     219             self.writer.add_histogram("Delta weights", torch.abs(self.delta_w_ac.flatten()), global_step=ep)
#     220             self.writer.add_scalars("Free energy", {"Training": self.energy(self.train_subset), "Validation": self.energy(self.validation_data)}, global_step=ep)
#
# AttributeError: 'bool' object has no attribute 'add_histogram'
